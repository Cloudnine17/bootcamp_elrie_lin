# %% [markdown]
# # Environment & Config Check
#
# Verify environment, .env variables, and NumPy functionality.

# %%
from dotenv import load_dotenv
import os
import numpy as np

# Load environment variables
load_dotenv()

# Verify API_KEY
api_key = os.getenv("API_KEY")
print(f"API_KEY present: {api_key is not None}")

# NumPy Mini-Demo
arr = np.array([2, 4, 6])
print("Array:", arr)
print("Mean:", arr.mean())
# Out:
# API_KEY present: True
# Array: [2 4 6]
# Mean: 4.0
